# %% [markdown]
# <a href="https://colab.research.google.com/github/jonrtaylor/FL_covid_data_notebooks/blob/master/DEPRECATED_FL_latest_caseline_file_with_death_updates.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### 9/20/2020: FLORIDA DEPARTMENT OF HEALTH NO LONGER UPDATES
###            THE EXCEL FILE USED BY THIS NOTEBOOK. COPIES OF
###            THESE FILES ARE AVAILABLE IN THE ARCHIVE.
###            -JON R. TAYLOR (@prof_jtaylor)


###   CLICK "Open in Colab" to get started ###

###   CLICK 'Runtime' ABOVE AND THEN CLICK 'Run all'

###   IF YOU TRY TO DOWNLOAD TODAY'S FILE BEFORE IT IS AVAILABLE THEN YOU WILL GET AN ERROR!!! ###

###   YOU WILL SEE A DATA TABLE BETWEEN THE TOP CELL AND THE BOTTOM CELL SHOWING YOU THE DATA IN THIS NOTEBOOK

###   THE LAST CELL CREATES A CSV FILE WHICH WILL DOWNLOAD TO YOUR PC

###   PLEASE SHARE THIS RESOURCE IF YOU FIND IT HELPFUL


import numpy as np
import pandas as pd
import time

today = time.strftime("%Y%m%d")

url = 'http://ww11.doh.state.fl.us/comm/_partners/covid19_report_archive/state_linelist_'

filepath = url+today+".xlsx"

with pd.ExcelFile(filepath) as xls:
    df1 = pd.read_excel(xls, 'Cases', skiprows=[0,1,2])
    df2 = pd.read_excel(xls, 'Deaths', skiprows=[0,1,2,3])

# %%
df1
# Out:
#           Case      County  ...     Jurisdiction       Date case counted
# 0            1     Alachua  ...      FL resident 2020-03-13 10:06:39.133
# 1            2     Alachua  ...      FL resident 2020-03-17 06:35:37.803
# 2            3     Alachua  ...      FL resident 2020-03-17 06:35:38.943
# 3            4     Alachua  ...      FL resident 2020-03-18 07:22:57.580
# 4            5     Alachua  ...      FL resident 2020-03-18 19:10:46.657
# ...        ...         ...  ...              ...                     ...
# 244146  244147  Washington  ...      FL resident 2020-07-09 19:47:23.057
# 244147  244148  Washington  ...  Non-FL resident 2020-06-01 19:27:34.507
# 244148  244149  Washington  ...  Non-FL resident 2020-06-01 19:47:34.067
# 244149  244150  Washington  ...  Non-FL resident 2020-07-03 12:01:27.347
# 244150  244151  Washington  ...  Non-FL resident 2020-07-08 17:43:56.503
#
# [244151 rows x 9 columns]

# %%
df2
# Out:
#       Death      County  ...       Date case counted Newly identified death
# 0         1     Alachua  ... 2020-04-09 15:03:46.653                    NaN
# 1         2     Alachua  ... 2020-04-09 15:33:15.147                    NaN
# 2         3     Alachua  ... 2020-04-09 23:34:04.850                    NaN
# 3         4     Alachua  ... 2020-04-09 23:34:08.597                    NaN
# 4         5     Alachua  ... 2020-04-18 06:03:56.600                    NaN
# ...     ...         ...  ...                     ...                    ...
# 4097   4098  Washington  ... 2020-05-24 18:55:32.690                    NaN
# 4098   4099  Washington  ... 2020-05-25 18:33:26.150                    NaN
# 4099   4100  Washington  ... 2020-05-28 19:01:08.470                    NaN
# 4100   4101  Washington  ... 2020-05-28 21:00:15.497                    NaN
# 4101   4102  Washington  ... 2020-06-04 18:21:02.443                    NaN
#
# [4102 rows x 10 columns]

# %%
df1.to_csv('latest_casefile.csv', index=False)
df2.to_csv('latest_casefile_deaths.csv', index=False)
from google.colab import files
files.download('latest_casefile.csv')
files.download('latest_casefile_deaths.csv')
