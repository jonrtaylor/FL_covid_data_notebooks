# %% [markdown]
# <a href="https://colab.research.google.com/github/jonrtaylor/FL_covid_data_notebooks/blob/master/CDC_USA_caseline_w_hospitalizations_to_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
###   CLICK "Open in Colab" to get started ###

###   CLICK 'Runtime' ABOVE AND THEN CLICK 'Run all'

###   YOU WILL SEE A DATA TABLE BETWEEN THE TOP CELL AND THE BOTTOM CELL SHOWING YOU THE DATA IN THIS NOTEBOOK

###   THE LAST CELL CREATES A CSV FILE WHICH WILL DOWNLOAD TO YOUR PC

###   PLEASE SHARE THIS RESOURCE IF YOU FIND IT HELPFUL


import numpy as np
import pandas as pd

df = pd.read_csv("https://data.cdc.gov/api/views/vbim-akqf/rows.csv?accessType=DOWNLOAD&api_foundry=true", parse_dates = ['cdc_report_dt', 'pos_spec_dt', 'onset_dt'],
                infer_datetime_format=True)

# %%
### show the first 20 rows of the dataframe

df.head(20)
# Out:
#    cdc_report_dt pos_spec_dt   onset_dt  ...   icu_yn death_yn medcond_yn
# 0     2020-03-03  2020-03-03        NaT  ...  Missing  Missing    Missing
# 1     2020-03-03  2020-03-03        NaT  ...  Missing  Missing    Missing
# 2     2020-04-07  2020-03-03 2020-03-03  ...  Missing  Missing    Missing
# 3     2020-08-04  2020-08-04        NaT  ...  Missing  Missing    Missing
# 4     2020-07-28  2020-08-04 2020-07-28  ...       No       No    Missing
# 5     2020-08-03  2020-08-04 2020-08-03  ...  Missing  Missing    Missing
# 6     2020-08-04  2020-08-04        NaT  ...  Unknown       No    Unknown
# 7     2020-08-04  2020-08-04        NaT  ...  Unknown       No    Unknown
# 8     2020-08-04  2020-08-04        NaT  ...  Unknown       No    Unknown
# 9     2020-08-04  2020-08-04        NaT  ...  Missing  Missing    Missing
# 10    2020-08-04  2020-08-04        NaT  ...  Missing  Missing    Missing
# 11    2020-08-04  2020-08-04        NaT  ...  Unknown       No    Unknown
# ...

# %%
### show information about the dataframe, giving number of rows, column names, datatype for each column

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3662325 entries, 0 to 3662324
# Data columns (total 11 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   cdc_report_dt                  datetime64[ns]
#  1   pos_spec_dt                    datetime64[ns]
#  2   onset_dt                       datetime64[ns]
#  3   current_status                 object
#  4   sex                            object
#  5   age_group                      object
#  6   Race and ethnicity (combined)  object
#  7   hosp_yn                        object
#  8   icu_yn                         object
#  9   death_yn                       object
#  10  medcond_yn                     object
# dtypes: datetime64[ns](3), object(8)
# memory usage: 307.4+ MB

# %%
### Identify the unique groupings of CDC's Age Group variable:

df.age_group.unique()
# Out:
# array(['0 - 9 Years', '10 - 19 Years', '20 - 29 Years', '30 - 39 Years',
#        '40 - 49 Years', '50 - 59 Years', '60 - 69 Years', '70 - 79 Years',
#        '80+ Years', nan, 'Unknown'], dtype=object)

# %%
### Example to show how to filter for a certain Age Group:

df[df.age_group == "0 - 9 Years"]
# Out:
#         cdc_report_dt pos_spec_dt   onset_dt  ...   icu_yn death_yn medcond_yn
# 0          2020-03-03  2020-03-03        NaT  ...  Missing  Missing    Missing
# 1          2020-03-03  2020-03-03        NaT  ...  Missing  Missing    Missing
# 2          2020-04-07  2020-03-03 2020-03-03  ...  Missing  Missing    Missing
# 3          2020-08-04  2020-08-04        NaT  ...  Missing  Missing    Missing
# 4          2020-07-28  2020-08-04 2020-07-28  ...       No       No    Missing
# ...               ...         ...        ...  ...      ...      ...        ...
# 3152987    2020-03-23  2020-03-15 2020-03-14  ...       No       No         No
# 3152988    2020-03-15  2020-03-15        NaT  ...  Missing  Missing    Missing
# 3152989    2020-03-20  2020-03-15        NaT  ...  Unknown  Unknown    Unknown
# 3152990    2020-03-18  2020-03-15        NaT  ...  Unknown  Unknown    Unknown
# 3152991    2020-03-20  2020-03-15        NaT  ...  Unknown  Unknown    Unknown
#
# ...

# %%
df.to_csv('CDC_USA_caseline_file.csv', index=False)
from google.colab import files
files.download('CDC_USA_caseline_file.csv')

# %%
#download only a single age group:

### NOTE ###

#delete the hash-tags (#) in front of the code in lines 7, 8, 9 and then run this cell to download the filtered CSV file:

#df2 = df[df['age_group'] == "0 - 9 Years"].copy()
#df2.to_csv('filtered_age_group_CDC_USA_caseline_file.csv', index=False)
#files.download('filtered_age_group_CDC_USA_caseline_file.csv')
